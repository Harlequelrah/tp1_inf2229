# %%
import requests
from bs4 import BeautifulSoup
import csv


# URL de la page contenant un tableau
url = "https://waytolearnx.com/2019/03/difference-entre-web-1-0-web-2-0-et-web-3-0.html"

response = requests.get(url)

html_content = response.content

soup = BeautifulSoup(html_content,'html.parser')

# %%
# recuperation du tableau
table = soup.find('table')

# recuperation des lignes
rows = table.find_all('tr')


# préparer les données
data = []

for row in rows :
    cols = row.find_all('td')
    cols = [col.text.strip() for col in cols]
    data.append(cols)


# Sauvegarder dans un fichier CSV
with open('diff_data.csv','w',newline='') as file :
    writer = csv.writer(file)
    writer.writerows(data)

print("Données sauvegardées dans diff_data.csv")
# Out:
# Données sauvegardées dans diff_data.csv
