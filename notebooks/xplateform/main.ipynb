# %%
import requests
import os


BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAJq99QEAAAAAkLBQqsGFUiczUXns2e2IhMezUy8%3DsPDG6CaxZSSEhsoYthk8KV1GJdA9LGZcl47my2GrTCu3uPkomK"

USERNAME = "xdevelrah"

def get_user_id(username):
    url = f"https://api.x.com/2/users/by/username/{username}"
    headers = {"Authorization": f"Bearer {BEARER_TOKEN}"}
    response  = requests.get(url,headers=headers)
    print(response.json())
    return response.json()["data"]["id"]

def get_user_tweets(user_id):
    url = f"https://api.x.com/2/users/{user_id}/teewts"
    headers = {"Authorization": f"Bearer {BEARER_TOKEN}"}
    params = {"max_resultats": 1}
    response = requests.get(url, headers=headers, params=params)
    return response

user_id=get_user_id(USERNAME)
tweets = get_user_tweets(user_id)

for tweet in tweets["data"]:
    print(tweet['tweet'])
# Out:
# {'account_id': 2051788177959014408, 'title': 'CreditsDepleted', 'detail': 'Your enrolled account [2051788177959014408] does not have any credits to fulfill this request.', 'type': 'https://api.twitter.com/2/problems/credits'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 23
#      19     params = {"max_resultats": 1}
#      20     response = requests.get(url, headers=headers, params=params)
#      21     return response
#      22
# ---> 23 user_id=get_user_id(USERNAME)
#      24 tweets = get_user_tweets(user_id)
#      25
#      26 for tweet in tweets["data"]:
#
# Cell In[2], line 14, in get_user_id(username)
#      10     url = f"https://api.x.com/2/users/by/username/{username}"
#      11     headers = {"Authorization": f"Bearer {BEARER_TOKEN}"}
#      12     response  = requests.get(url,headers=headers)
#      13     print(response.json())
# ---> 14     return response.json()["data"]["id"]
#
# KeyError: 'data'
